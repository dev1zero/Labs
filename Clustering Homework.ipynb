# %%
from sklearn import datasets
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import numpy as np

# %matplotlib inline

# %%
iris = datasets.load_iris()
X = iris.data
df = pd.DataFrame(X)
df.columns = iris.feature_names

# %% [markdown]
# The dataset we're using today contains information about flowers called an iris.  We're going to use K-Means clustering to atttempt to identify unique types of iris.
#
# Step 1:  Use my method below to identify how many groups are in the dataset.
#
# Step 2:  add the kmeans cluster labels into the dataframe df.

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
X = df

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
def find_k (X, k_range, sample_percent=1):
    """
    k_range: a list of possible k values
    X, the data we're clustering on
    """
    from sklearn.cluster import KMeans
    import matplotlib.pyplot as plt
    import numpy as np
    from scipy.spatial.distance import cdist
    from sklearn.metrics import pairwise_distances

    N = X.shape[0]
    sampleSize = X.shape[0] * sample_percent

    if sampleSize > 0:
        index = np.arange(np.shape(X)[0])
        np.random.shuffle(index)
        X =  X[index, :]


    mean_distortions=[]
    for k in k_range:
        #cluster using k, then calculate the mean distortion (average distance to closest centroid)
        kmeans_model = KMeans(n_clusters=k, init='k-means++', n_jobs=-1).fit(X)
        mean_distortions.append(sum(np.min(pairwise_distances(X, kmeans_model.cluster_centers_,
                                                              metric='euclidean'),axis=1)) / X.shape[0])


    #visualize results
    plt.plot(k_range, mean_distortions)
    plt.xlabel("K Value")
    plt.ylabel("Mean Distortion")
    plt.title("Elbow Graph for Mean Distortion per K")
    plt.show()

# %%
find_k(np.matrix(X), range(1,10),1)

# %% [markdown]
# Trying kmeans for the 3 different elbows in the plot.

# %%
kmeans_model = KMeans(n_clusters=2, random_state=42)
kmeans_model2.fit(X_scaled)

kmeans_model3 = KMeans(n_clusters=3, random_state=42)
kmeans_model3.fit(X_scaled)

kmeans_model5 = KMeans(n_clusters=5, random_state=42)
kmeans_model5.fit(X_scaled)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5, n_init=10,
#     n_jobs=1, precompute_distances=True, random_state=42, tol=0.0001,
#     verbose=0)

# %%
df['lables2'] = kmeans_model2.labels_
df['lables3'] = kmeans_model3.labels_
df['lables5'] = kmeans_model5.labels_

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.032057          -1.341272         -1.312977
# 1          -1.143017         -0.124958          -1.341272         -1.312977
# 2          -1.385353          0.337848          -1.398138         -1.312977
# 3          -1.506521          0.106445          -1.284407         -1.312977
# 4          -1.021849          1.263460          -1.341272         -1.312977
#
#    lables2  lables3  lables5
# 0        1        1        1
# 1        1        1        2
# 2        1        1        2
# 3        1        1        2
# 4        1        1        1

# %%
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0            -0.900681          1.032057          -1.341272         -1.312977
# 1            -1.143017         -0.124958          -1.341272         -1.312977
# 2            -1.385353          0.337848          -1.398138         -1.312977
# 3            -1.506521          0.106445          -1.284407         -1.312977
# 4            -1.021849          1.263460          -1.341272         -1.312977
# 5            -0.537178          1.957669          -1.170675         -1.050031
# 6            -1.506521          0.800654          -1.341272         -1.181504
# 7            -1.021849          0.800654          -1.284407         -1.312977
# 8            -1.748856         -0.356361          -1.341272         -1.312977
# 9            -1.143017          0.106445          -1.284407         -1.444450
# 10           -0.537178          1.494863          -1.284407         -1.312977
# ...

# %%
from sklearn.manifold import TSNE
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

model = TSNE(n_components=3, learning_rate=12, random_state=10)
X_tsne = model.fit_transform(X)
plt.figure(figsize=(10,10))
ax = plt.subplot(111,projection='3d')
ax.scatter(X_tsne[:,0],X_tsne[:,1],X_tsne[:,2], c=kmeans_model3.labels_)
