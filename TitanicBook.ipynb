# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.PassengerId.hist(bins=6)
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# ...
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Length: 891, dtype: int64

# %%
df.Survived.hist(bins=2)
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# dtype: int64

# %%
df.Sex.value_counts().plot(kind='bar')
df.Sex.value_counts()
# Out:
# male      577
# female    314
# dtype: int64

# %%
df.Pclass.hist()
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
df.Age.hist(bins=6)
df.Age.value_counts()
# Out:
# 24    30
# 22    27
# 18    26
# 28    25
# 30    25
# 19    25
# 21    24
# 25    23
# 36    22
# 29    20
# 35    18
# 27    18
# 32    18
# 26    18
# 16    17
# ...
# 14.50    1
# 55.50    1
# 0.67     1
# 0.92     1
# 24.50    1
# 36.50    1
# 23.50    1
# 80.00    1
# 12.00    1
# 74.00    1
# 70.50    1
# 0.42     1
# 66.00    1
# 53.00    1
# 34.50    1
# Length: 88, dtype: int64

# %%
df.SibSp.hist()
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# dtype: int64

# %%
df.Parch.hist()
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# dtype: int64

# %%
df.Ticket.value_counts().plot(kind='bar')
df.Ticket.value_counts()
# Out:
# 347082          7
# 1601            7
# CA. 2343        7
# CA 2144         6
# 3101295         6
# 347088          6
# 382652          5
# S.O.C. 14879    5
# 349909          4
# W./C. 6608      4
# 17421           4
# 113760          4
# 19950           4
# PC 17757        4
# 2666            4
# ...
# 7598                  1
# 363294                1
# 349213                1
# A/5 2817              1
# SOTON/O.Q. 3101311    1
# 112050                1
# 2664                  1
# 349912                1
# 345780                1
# 4138                  1
# 343275                1
# 11752                 1
# 2695                  1
# 349236                1
# PC 17592              1
# Length: 681, dtype: int64

# %%
df.Fare.hist(bins=5)
df.Fare.value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
# 10.5000    24
# 7.9250     18
# 7.7750     16
# 0.0000     15
# 26.5500    15
# 7.2292     15
# 8.6625     13
# 7.8542     13
# 7.2500     13
# 7.2250     12
# ...
# 81.8583    1
# 25.5875    1
# 32.3208    1
# 34.6542    1
# 12.5250    1
# 35.0000    1
# 7.6292     1
# 8.3625     1
# 9.8417     1
# 9.8458     1
# 15.5500    1
# 7.0458     1
# 8.4333     1
# 16.0000    1
# 6.9500     1
# Length: 248, dtype: int64

# %%
df.Cabin.value_counts().plot(kind='bar')
df.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F2             3
# D              3
# E101           3
# F33            3
# D33            2
# C83            2
# C124           2
# C2             2
# B77            2
# C123           2
# F G73          2
# ...
# B80        1
# C7         1
# B39        1
# A34        1
# B3         1
# B50        1
# A7         1
# B41        1
# F E69      1
# B37        1
# B82 B84    1
# D6         1
# D45        1
# B30        1
# C104       1
# Length: 147, dtype: int64

# %%
df.Embarked.value_counts().plot(kind='bar')
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# dtype: int64

# %%
"Min, Max, Mean Stdv for continous columns"
# Out:
# 'Min, Max, Mean Stdv for continous columns'

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
###"Checking columns for null"

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Name.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dNullAge = df[df.Age.isnull()]

# %%
dNullAge.shape
# Out:
# (177, 12)

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
dNullCabin = df[df.Cabin.isnull()]

# %%
dNullCabin.shape
# Out:
# (687, 12)

# %%
dNullEmbarked = df[df.Embarked.isnull()]

# %%
dNullEmbarked.shape
# Out:
# (2, 12)

# %%
#Survivor plot by sex
fig, axs = plt.subplots(1,2)
df[df.Sex=='male'].Survived.value_counts().plot(kind='barh', ax=axs[0], title="Male Survivor")
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh', ax=axs[1], title="Female Survivor")

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# dtype: int64

# %%
#number of people in class 3 that survived
df[df.Pclass == 3].Survived.value_counts()
# Out:
# 0    372
# 1    119
# dtype: int64

# %%
#number of people in class 2 that survived
df[df.Pclass == 2].Survived.value_counts()
# Out:
# 0    97
# 1    87
# dtype: int64

# %%
#number of people in class 1 that survived
df[df.Pclass == 1].Survived.value_counts()
# Out:
# 1    136
# 0     80
# dtype: int64

# %%
#Survivor plot by class
fig, axs = plt.subplots(1,3)
df[df.Pclass == 1].Survived.value_counts().plot(kind='bar', ax=axs[0], title="Class 1 Survivors")
df[df.Pclass == 2].Survived.value_counts().plot(kind='bar', ax=axs[1], title="Class 2 Survivors")
df[df.Pclass == 3].Survived.value_counts().plot(kind='bar', ax=axs[2], title="Class 3 Survivors")

# %%
#child Survivors
df[df.Age < 18].Survived.value_counts()
# Out:
# 1    61
# 0    52
# dtype: int64

# %%
#Adult Survivors
df[df.Age > 18].Survived.value_counts()
# Out:
# 0    355
# 1    220
# dtype: int64

# %%
#Survivor plots for children and adults
fig, axs = plt.subplots(1,2)
df[df.Age < 18].Survived.value_counts().plot(kind='bar', ax=axs[0], title="Child Survivors")
df[df.Age > 18].Survived.value_counts().plot(kind='bar', ax=axs[1], title="Adult Survivors")
